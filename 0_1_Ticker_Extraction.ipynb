# %%
import pandas as pd
ASX_data = pd.read_csv('https://www.asx.com.au/asx/research/ASXListedCompanies.csv',skiprows=1)
# format to align with yahoo finance ticker
ASX_data["Ticker"] = ASX_data['ASX code']+".AX"
ASX_TICKER_LIST = list(ASX_data['Ticker'])

# %%
# test conversion
temp = ASX_data[(ASX_data['GICS industry group'] == "Banks")]
temp
# Out:
#                                          Company name ASX code  \
# 226   AUSTRALIA AND NEW ZEALAND BANKING GROUP LIMITED      ANZ
# 235                      AUSTRALIAN FINANCE GROUP LTD      AFG
# 253                                  AUSWIDE BANK LTD      ABA
# 272                       BANK OF QUEENSLAND LIMITED.      BOQ
# 294                 BENDIGO AND ADELAIDE BANK LIMITED      BEN
# 335                   BNK BANKING CORPORATION LIMITED      BBC
# 489                   COMMONWEALTH BANK OF AUSTRALIA.      CBA
# 797     GENWORTH MORTGAGE INSURANCE AUSTRALIA LIMITED      GMA
# 863                  HEARTLAND GROUP HOLDINGS LIMITED      HGH
# 1038                          KINA SECURITIES LIMITED      KSL
# 1269                          MORTGAGE CHOICE LIMITED      MOC
# 1287                                  MYSTATE LIMITED      MYS
# 1288                              N1 HOLDINGS LIMITED      N1H
# 1297                  NATIONAL AUSTRALIA BANK LIMITED      NAB
# 1629                                RESIMAC GROUP LTD      RMC
# 2021                              VIRGIN MONEY UK PLC      VUK
# 2073                      WESTPAC BANKING CORPORATION      WBC
# 2112               YELLOW BRICK ROAD HOLDINGS LIMITED      YBR
#
#      GICS industry group  Ticker
# 226                Banks  ANZ.AX
# 235                Banks  AFG.AX
# 253                Banks  ABA.AX
# 272                Banks  BOQ.AX
# 294                Banks  BEN.AX
# 335                Banks  BBC.AX
# 489                Banks  CBA.AX
# 797                Banks  GMA.AX
# 863                Banks  HGH.AX
# 1038               Banks  KSL.AX
# 1269               Banks  MOC.AX
# 1287               Banks  MYS.AX
# 1288               Banks  N1H.AX
# 1297               Banks  NAB.AX
# 1629               Banks  RMC.AX
# 2021               Banks  VUK.AX
# 2073               Banks  WBC.AX
# 2112               Banks  YBR.AX
