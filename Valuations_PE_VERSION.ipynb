# %%
#Value companies based on the following attributes, and compare against current stock price
#revenue
#profit margin
#number of shares
#P/E ratio

#Revenue * profit margin / #share * P/E ratio

# %%
import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt
import seaborn as sns

#!pip install yfinance --upgrade --no-cache-dir
#!pip uninstall yfinance
#!pip install git+https://github.com/rodrigobercini/yfinance.git
import yfinance as yf
import yahoofinancials as yfin

# %%
#tick = yf.Ticker("APT.AX")
#tick.info

# %%
import time
start_time = time.time()


company_df = pd.DataFrame()

def Info_Extract(TickName):
    
    global company_df
    
    try:
        tick = yf.Ticker(TickName)
        #filter_df = tick.info
        temp_df = tick.info

        filter_df = {key: temp_df[key] for key in temp_df.keys() 
                                   & {'symbol','enterpriseValue','enterpriseToRevenue', 'profitMargins','sharesOutstanding','trailingPE','regularMarketPreviousClose'}} 

        #ROW_DF = pd.DataFrame.from_dict(filter_df,orient='index',columns=[TickName]).transpose()

        company_df = company_df.append(filter_df, ignore_index=True) 
         
    except Exception:
        print("Error with",TickName)
        pass

    return()


#for company in ["CBA.AX", "WBC.AX", "NAB.AX", "ANZ.AX", "MQG.AX", "ASX.AX", "IAG.AX", "SUN.AX", "QBE.AX", "MFG.AX", "MPL.AX", "AMP.AX", "BEN.AX", "CGF.AX", "NHF.AX", "BOQ.AX", "SDF.AX", "PTM.AX", "NWL.AX", "PDL.AX", "GOLD.AX", "IFL.AX", "PPT.AX", "VUK.AX", "JHG.AX", "IMF.AX", "GMA.AX", "HGH.AX", "CNI.AX", "CCP.AX", "AUB.AX", "Z1P.AX", "PSI.AX", "VGI.AX", "PNI.AX", "HUB.AX", "EQT.AX", "AEF.AX", "NGI.AX", "MYS.AX", "OFX.AX", "FXL.AX", "AFG.AX", "PWG.AX", "MOE.AX", "BFG.AX", "RMC.AX", "TWR.AX", "MNY.AX", "ECX.AX", "PAC.AX", "ABA.AX", "APD.AX", "KSL.AX", "CLH.AX", "CVW.AX", "ED1.AX", "FID.AX", "CVC.AX", "EZL.AX", "FSA.AX", "TOT.AX", "WZR.AX", "MME.AX", "PCG.AX", "CCV.AX", "CGR.AX", "MOC.AX", "GOW.AX", "COG.AX", "BTI.AX", "PGL.AX", "AFA.AX", "GDG.AX", "TIP.AX", "SZL.AX", "OVH.AX", "MAI.AX", "EDC.AX", "BBC.AX", "MEC.AX", "OPY.AX", "MAM.AX", "AYI.AX", "8IH.AX", "ASW.AX", "NSX.AX", "RZI.AX", "QFE.AX", "EAS.AX", "PNC.AX", "CWZ.AX", "CIW.AX", "LAW.AX", "SEQ.AX", "BWF.AX", "SWF.AX", "PWL.AX", "YBR.AX", "XPL.AX", "EVE.AX", "BLA.AX", "CGA.AX", "FEI.AX", "CA8.AX", "KBC.AX", "SOR.AX", "CAF.AX", "IQ3.AX", "LCE.AX", "PFG.AX", "INV.AX", "ENA.AX", "AVC.AX", "N1H.AX", "KAM.AX", "DCL.AX", "FIG.AX", "FFG.AX", "BIR.AX", "WTL.AX", "EXO.AX", "ARC.AX", "IPC.AX", "MCX.AX", "MJC.AX", "PLC.AX", "PVL.AX", "MPR.AX", "QUE.AX", "SAM.AX", "OEQ.AX", "CINPA.AX", "SSLPA.AX", "WHFPA.AX"]:
for company in ["ZIM.AX", "ZEL.AX", "Z1P.AX", "YAL.AX", "XRO.AX", "WTC.AX", "WSA.AX", "WPP.AX", "WPL.AX", "WOW.AX", "WOR.AX", "WJA.AX", "WHC.AX", "WHA.AX", "WGX.AX", "WGN.AX", "WES.AX", "WEB.AX", "WBC.AX", "WAF.AX", "VVR.AX", "VUK.AX", "VTH.AX", "VTG.AX", "VRT.AX", "VRL.AX", "VOC.AX", "VHT.AX", "VEA.AX", "VCX.AX", "VAH.AX", "URW.AX", "URF.AX", "UOS.AX", "UMG.AX", "TZN.AX", "TWE.AX", "TPM.AX", "TNE.AX", "TLS.AX", "TGR.AX", "TGP.AX", "TGN.AX", "TER.AX", "TCL.AX", "TBR.AX", "TAH.AX", "SYR.AX", "SYD.AX", "SXY.AX", "SXL.AX", "SXE.AX", "SWM.AX", "SVW.AX", "SUN.AX", "SUL.AX", "STX.AX", "STO.AX", "SST.AX", "SSM.AX", "SRV.AX", "SRG.AX", "SPL.AX", "SPK.AX", "SOL.AX", "SNL.AX", "SMR.AX", "SM1.AX", "SLR.AX", "SLK.AX", "SLC.AX", "SKT.AX", "SKI.AX", "SKC.AX", "SIQ.AX", "SIG.AX", "SHV.AX", "SHL.AX", "SHJ.AX", "SGR.AX", "SGP.AX", "SGM.AX", "SGH.AX", "SGF.AX", "SFX.AX", "SFR.AX", "SFG.AX", "SFC.AX", "SEK.AX", "SDG.AX", "SDF.AX", "SDA.AX", "SCP.AX", "SCG.AX", "SBM.AX", "SAR.AX", "S32.AX", "RWC.AX", "RUL.AX", "RSG.AX", "RRL.AX", "RMS.AX", "RMD.AX", "RMC.AX", "RIO.AX", "RIC.AX", "RHP.AX", "RHC.AX", "RFF.AX", "REX.AX", "REH.AX", "REG.AX", "REA.AX", "RDC.AX", "RCT.AX", "RBL.AX", "QUB.AX", "QIP.AX", "QBE.AX", "QAN.AX", "PWH.AX", "PVS.AX", "PTM.AX", "PSQ.AX", "PSI.AX", "PRU.AX", "PRN.AX", "PPT.AX", "PPS.AX", "PPH.AX", "PPG.AX", "PPE.AX", "PPC.AX", "PNV.AX", "PNR.AX", "PNI.AX", "PMV.AX", "PME.AX", "PLS.AX", "PGH.AX", "PGC.AX", "PFP.AX", "PET.AX", "PDN.AX", "PDL.AX", "PCG.AX", "PAR.AX", "PAN.AX", "PAC.AX", "OZL.AX", "OVH.AX", "OTW.AX", "OSH.AX", "ORI.AX", "ORG.AX", "ORE.AX", "ORA.AX", "OPT.AX", "ONT.AX", "OML.AX", "OMH.AX", "OGC.AX", "OFX.AX", "OCL.AX", "OBL.AX", "NXT.AX", "NWS.AX", "NWL.AX", "NWH.AX", "NUF.AX", "NST.AX", "NSR.AX", "NMT.AX", "NIC.AX", "NHF.AX", "NHC.AX", "NGI.AX", "NEW.AX", "NEU.AX", "NEC.AX", "NEA.AX", "NCZ.AX", "NCM.AX", "NCK.AX", "NAN.AX", "NAB.AX", "MYX.AX", "MYS.AX", "MYR.AX", "MWY.AX", "MVP.AX", "MVF.AX", "MTS.AX", "MTO.AX", "MSB.AX", "MRM.AX", "MQG.AX", "MPL.AX", "MP1.AX", "MOZ.AX", "MOE.AX", "MOC.AX", "MNY.AX", "MNS.AX", "MNF.AX", "MND.AX", "MMS.AX", "MMI.AX", "MLX.AX", "MLD.AX", "MIN.AX", "MHJ.AX", "MGX.AX", "MGR.AX", "MFG.AX", "MEZ.AX", "MCP.AX", "MAQ.AX", "MAH.AX", "LYL.AX", "LYC.AX", "LVT.AX", "LVH.AX", "LOV.AX", "LNK.AX", "LNG.AX", "LLC.AX", "LIC.AX", "LEP.AX", "KSL.AX", "KSC.AX", "KMD.AX", "KGN.AX", "KAR.AX", "JMS.AX", "JLG.AX", "JIN.AX", "JHX.AX", "JHG.AX", "JHC.AX", "JBH.AX", "IVC.AX", "ITG.AX", "ISX.AX", "ISU.AX", "IRI.AX", "IRE.AX", "IPL.AX", "IPH.AX", "INR.AX", "ING.AX", "INA.AX", "IMD.AX", "ILU.AX", "IGO.AX", "IGL.AX", "IFN.AX", "IFM.AX", "IFL.AX", "IEL.AX", "IDX.AX", "IAP.AX", "IAG.AX", "HZN.AX", "HVN.AX", "HUO.AX", "HUB.AX", "HTA.AX", "HT1.AX", "HSN.AX", "HRR.AX", "HPI.AX", "HLS.AX", "HLO.AX", "HFR.AX", "HE8.AX", "HAS.AX", "GXY.AX", "GWA.AX", "GUD.AX", "GTN.AX", "GRR.AX", "GPT.AX", "GOZ.AX", "GOW.AX", "GOR.AX", "GNG.AX", "GNE.AX", "GNC.AX", "GMG.AX", "GMA.AX", "GLL.AX", "GEM.AX", "GDI.AX", "GDF.AX", "FXL.AX", "FWD.AX", "FSA.AX", "FRI.AX", "FPH.AX", "FNP.AX", "FMS.AX", "FMG.AX", "FLT.AX", "FLN.AX", "FLC.AX", "FID.AX", "FBU.AX", "FBR.AX", "FAR.AX", "EZL.AX", "EXP.AX", "EWC.AX", "EVT.AX", "EVN.AX", "ERF.AX", "ERA.AX", "EQT.AX", "EOS.AX", "ENN.AX", "EML.AX", "ELO.AX", "ELD.AX", "EHL.AX", "EHE.AX", "EGN.AX", "ED1.AX", "ECX.AX", "DXS.AX", "DWS.AX", "DTL.AX", "DOW.AX", "DNK.AX", "DMP.AX", "DHG.AX", "DDR.AX", "DCN.AX", "DCG.AX", "CWY.AX", "CWP.AX", "CWN.AX", "CVW.AX", "CVN.AX", "CVC.AX", "CUV.AX", "CTX.AX", "CTD.AX", "CSR.AX", "CSL.AX", "CRN.AX", "CQR.AX", "CQE.AX", "CPU.AX", "COL.AX", "COI.AX", "COH.AX", "COG.AX", "COF.AX", "COE.AX", "CNU.AX", "CNI.AX", "CMW.AX", "CLW.AX", "CLV.AX", "CLQ.AX", "CLH.AX", "CL1.AX", "CKF.AX", "CIP.AX", "CIM.AX", "CII.AX", "CIA.AX", "CHC.AX", "CGL.AX", "CGF.AX", "CGC.AX", "CEN.AX", "CDV.AX", "CDP.AX", "CDD.AX", "CDA.AX", "CCX.AX", "CCV.AX", "CCP.AX", "CCL.AX", "CBA.AX", "CAT.AX", "CAR.AX", "CAN.AX", "CAJ.AX", "BYE.AX", "BXB.AX", "BWX.AX", "BWP.AX", "BVS.AX", "BUB.AX", "BSL.AX", "BSE.AX", "BRL.AX", "BRG.AX", "BPT.AX", "BOQ.AX", "BLX.AX", "BLD.AX", "BKW.AX", "BKL.AX", "BIN.AX", "BHP.AX", "BGL.AX", "BGA.AX", "BFG.AX", "BEN.AX", "BBN.AX", "BAP.AX", "AZJ.AX", "AYS.AX", "AX1.AX", "AWC.AX", "AVZ.AX", "AVN.AX", "AVJ.AX", "AVH.AX", "AVG.AX", "AUZ.AX", "AUB.AX", "ATS.AX", "ATL.AX", "ASX.AX", "AST.AX", "ASG.AX", "ASB.AX", "ARQ.AX", "ARF.AX", "ARB.AX", "AQZ.AX", "AQR.AX", "AQG.AX", "APX.AX", "APT.AX", "API.AX", "APE.AX", "APD.AX", "APA.AX", "AOF.AX", "ANZ.AX", "ANN.AX", "AMP.AX", "AML.AX", "AMI.AX", "AMC.AX", "AMA.AX", "ALX.AX", "ALU.AX", "ALQ.AX", "ALL.AX", "ALG.AX", "AKP.AX", "AJM.AX", "AJL.AX", "AIA.AX", "AHY.AX", "AGY.AX", "AGL.AX", "AGI.AX", "AGG.AX", "AFG.AX", "AEF.AX", "ADI.AX", "ADH.AX", "AD8.AX", "AC8.AX", "ABP.AX", "ABC.AX", "ABA.AX", "AAC.AX", "A2M.AX", "A2B.AX", "3PL.AX"]:
#for company in ["CBA.AX", "NAB.AX","BEN.AX"]:
    Info_Extract(company)
    #print(output.head())   
    
    
    #company_df = company_df.append(x, ignore_index=True)
    #

DF=company_df
DF['SHARE_VAL_PE_BASED'] = (DF['enterpriseValue']/DF['enterpriseToRevenue']) * DF['profitMargins']/DF['sharesOutstanding']*DF['trailingPE']
DF['SHARE_VAL_TO_GAIN'] = DF['SHARE_VAL_PE_BASED'] - DF['regularMarketPreviousClose']

    
DF.head().sort_values(by=['SHARE_VAL_TO_GAIN'],ascending=False)    


print("--- %s seconds ---" % (time.time() - start_time))

#Keep all vars: 15 seconds
#Keep part of vars: 12 seconds

# %%
DF2 = DF.sort_values(by=['profitMargins'],ascending=False).dropna()   

DF2.head(10)

DF.to_excel("/Users/JZ/Downloads/ALL_ORDS_500.xlsx", sheet_name='Sheet_name_1')
# Out:
#    enterpriseToRevenue  enterpriseValue  profitMargins  \
# 0               11.819     2.725906e+11        0.43934
# 1               10.416     1.648473e+11        0.21590
# 2               -0.033    -5.046438e+07        0.20688
#
#    regularMarketPreviousClose  sharesOutstanding  symbol  trailingPE  \
# 0                       65.73       1.770240e+09  CBA.AX   11.561480
# 1                       18.79       3.196220e+09  NAB.AX   15.650263
# 2                        6.55       4.928410e+08  BEN.AX   10.388514
#
#    SHARE_VAL_PE_BASED  SHARE_VAL_TO_GAIN
# 0           66.177777           0.447777
# 1           16.730871          -2.059129
# 2            6.668622           0.118622

# %%
DF=company_df

DF['SHARE_VAL_PE_BASED'] = (DF['enterpriseValue']/DF['enterpriseToRevenue']) * DF['profitMargins']/DF['sharesOutstanding']*DF['trailingPE']
#DF_COMPARE = DF_CALCS['SHARE_VAL_PE_BASED'] - DF_CALCS['regularMarketPreviousClose']

DF.head()
# Out:
#    enterpriseToRevenue  profitMargins  regularMarketPreviousClose  \
# 0               11.819        0.43934                       65.73
# 1               10.416        0.21590                       18.79
# 2                0.496        0.26521                       18.74
# 3               10.065        0.25846                       18.39
# 4                0.977        0.04237                       34.78
#
#    sharesOutstanding  symbol  trailingPE  SHARE_VAL_PE_BASED
# 0       1.770240e+09  CBA.AX   11.561480           67.825461
# 1       3.196220e+09  NAB.AX   15.650263           22.022600
# 2       2.836180e+09  ANZ.AX   12.287087            1.139769
# 3       3.609220e+09  WBC.AX   12.774480           18.414800
# 4       1.263090e+09  WOW.AX   17.383177            1.139404
