# %%
#Import tickers


#Extract information, lots of try and excepts
#Append data - fundamentals
#Append data - historical prices


# Calculate features
# 

#Export to excel

# %%
import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt
import seaborn as sns

#!pip install yfinance --upgrade --no-cache-dir
#!pip uninstall yfinance
#!pip install git+https://github.com/rodrigobercini/yfinance.git
import yfinance as yf
import yahoofinancials as yfin

# %%
#For 1 company
    
#tick = yf.Ticker("CBA.AX")

#BOQ.AX doesn't work sometimes
#tick = yf.Ticker("WLC.AX")
tick = yf.Ticker("WLC.AX")

for i in tick.info:
    try:
        INF = tick.info
    except KeyError:
        continue
               

#INF = tick.info

#FIN = tick.financials.transpose()
#BS = tick.balance_sheet.transpose()
#DIV = tick.dividends
#CF = tick.cashflow
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-d60c7b7b41f6> in <module>
#       7 tick = yf.Ticker("WLC.AX")
#       8
# ----> 9 for i in tick.info:
#      10     try:
#      11         INF = tick.info
#
# ~/opt/anaconda3/lib/python3.7/site-packages/yfinance/ticker.py in info(self)
#     136     @property
#     137     def info(self):
# --> 138         return self.get_info()
#     139
#     140     @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/yfinance/base.py in get_info(self, proxy, as_dict, *args, **kwargs)
#     422
#     423     def get_info(self, proxy=None, as_dict=False, *args, **kwargs):
# --> 424         self._get_fundamentals(proxy)
#     425         data = self._info
#     426         if as_dict:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/yfinance/base.py in _get_fundamentals(self, kind, proxy)
# ...

# %%
INF
# Out:
# {'zip': '4006',
#  'sector': 'Financial Services',
#  'fullTimeEmployees': 1996,
# ...
